# %% [markdown]
# # Loading Data

# %%
import pandas as pd

data = pd.read_csv('E:\Final_Data.csv', index_col=0)
#data.head()
#data.info()
data
# Out:
#                                                  Title  \
# 0    punishment crimes committed substance susch co...
# 1                  punishment abduction wimen children
# 2                                    punishment ransom
# 3                      punishment rapem death due rape
# 4             punishment inciting women commit suicide
# ..                                                 ...
# 195              adulteration food drink intended sale
# 196                                   punishment theft
# 197                            theft dwellinghouse etc
# 198  theft preparation made causing death hurt rest...
# 199     theft clerk servant property possession master
#
#                                                Content
# 0    person kills attempts cause death child woman ...
# 1    person human trafficking prevention suppressio...
# 2    person detains woman child ransom person shall...
# 3    man rapes woman child shall punishable death p...
# 4    woman commits suicide without consent woman pe...
# ..                                                 ...
# 195  whoever adulterates article food drink make ar...
# 196  whoever commits theft shall punished imprisonm...
# 197  whoever commits theft building tent vessel bui...
# 198  whoever commits theft made preparation causing...
# 199  whoever clerk servant employed capacity clerk ...
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Cleaning Data

# %%
def clean_again(x):
    x = str(x).replace('whoever', '')
    x = str(x).replace('shall', '')
    x = str(x).replace('person', '')
    return x

# %%
data['Content'] = data['Content'].apply(lambda x: clean_again(x))
data.head()
# Out:
#                                                Title  \
# 0  punishment crimes committed substance susch co...
# 1                punishment abduction wimen children
# 2                                  punishment ransom
# 3                    punishment rapem death due rape
# 4           punishment inciting women commit suicide
#
#                                              Content
# 0   kills attempts cause death child woman burnin...
# 1   human trafficking prevention suppression act ...
# 2   detains woman child ransom  liable death life...
# 3  man rapes woman child punishable death penalty...
# 4  woman commits suicide without consent woman  d...

# %% [markdown]
# # TF-IDF (Feature Extraction)
# ### Source of tf-idf: https://medium.com/@cmukesh8688/tf-idf-vectorizer-scikit-learn-dbc0244a911a

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#unicode
documents = data['Content'].values.astype("U")

vectorizer = TfidfVectorizer(stop_words='english')
features = vectorizer.fit_transform(documents)
features
# Out:
# <200x1094 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4662 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Clustering
# ### Source of clustering: https://www.youtube.com/watch?v=ORpDAUQUnkU

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=8, init = 'k-means++', max_iter = 10, n_init = 1)
model.fit(features)

data['Cluster'] = model.labels_
data.to_csv('Pre_Label_Data.csv')
data
# Out:
#                                                  Title  \
# 0    punishment crimes committed substance susch co...
# 1                  punishment abduction wimen children
# 2                                    punishment ransom
# 3                      punishment rapem death due rape
# 4             punishment inciting women commit suicide
# ..                                                 ...
# 195              adulteration food drink intended sale
# 196                                   punishment theft
# 197                            theft dwellinghouse etc
# 198  theft preparation made causing death hurt rest...
# 199     theft clerk servant property possession master
#
#                                                Content  Cluster
# 0     kills attempts cause death child woman burnin...        1
# 1     human trafficking prevention suppression act ...        1
# 2     detains woman child ransom  liable death life...        1
# 3    man rapes woman child punishable death penalty...        1
# 4    woman commits suicide without consent woman  d...        1
# ..                                                 ...      ...
# 195  adulterates article food drink make article no...        7
# 196  commits theft punished imprisonment either des...        4
# 197  commits theft building tent vessel building te...        4
# 198  commits theft made preparation causing death h...        4
# 199  clerk servant employed capacity clerk servant ...        4
#
# [200 rows x 3 columns]

# %% [markdown]
# # Printing top 10 features of the clusters

# %%
print("Cluster Centraoids: \n")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(8):
    print("Cluster %d:" % i)
    for j in order_centroids[i, :30]:
        print(' %s,'%terms[j])
    print('-------------')
# Out:
# Cluster Centraoids:
#
# Cluster 0:
#  false,
#  offence,
#  evidence,
#  convicted,
#  gives,
#  weapon,
#  cause,
#  punishable,
#  knowing,
#  extend,
#  imprisonment,
#  true,
#  likely,
#  gave,
#  punished,
#  years,
#  fine,
#  certificate,
#  term,
#  armed,
#  believe,
#  description,
#  uses,
#  drug,
#  section,
#  knows,
#  used,
#  deadly,
#  declaration,
#  warranty,
# -------------
# Cluster 1:
#  act,
#  child,
#  woman,
#  death,
#  hurt,
#  years,
#  imprisonment,
#  extend,
#  causes,
#  fine,
#  term,
#  description,
#  section,
#  punished,
#  life,
#  grievous,
#  punishable,
#  caused,
#  means,
#  case,
#  cause,
#  guilty,
#  voluntarily,
#  substance,
#  human,
#  intention,
#  homicide,
#  culpable,
#  provided,
#  taka,
# -------------
# Cluster 2:
#  public,
#  servant,
#  property,
#  extend,
#  duty,
#  term,
#  fine,
#  discharge,
#  imprisonment,
#  description,
#  punished,
#  injury,
#  lawful,
#  cause,
#  taka,
#  knows,
#  years,
#  office,
#  knowing,
#  sale,
#  authority,
#  obstructs,
#  legally,
#  intending,
#  taken,
#  likely,
#  months,
#  act,
#  functions,
#  bound,
# -------------
# Cluster 3:
#  officer,
#  sailor,
#  soldier,
#  airman,
#  air,
#  navy,
#  army,
#  bangladesh,
#  force,
#  abets,
#  mutiny,
#  assault,
#  abetment,
#  magistrate,
#  consequence,
#  insubordination,
#  description,
#  committed,
#  extend,
#  superior,
#  imprisonment,
#  office,
#  term,
#  liable,
#  years,
#  punished,
#  committing,
#  execution,
#  fine,
#  desertion,
# -------------
# Cluster 4:
#  commits,
#  imprisonment,
#  punished,
#  description,
#  theft,
#  fine,
#  assembly,
#  extend,
#  term,
#  years,
#  suicide,
#  life,
#  unlawful,
#  engaged,
#  liable,
#  death,
#  murder,
#  year,
#  hired,
#  section,
#  depredation,
#  bribery,
#  property,
#  woman,
#  months,
#  disturbance,
#  offence,
#  performance,
#  member,
#  clerk,
# -------------
# Cluster 5:
#  wrongfully,
#  prisoner,
#  confines,
#  confined,
#  extend,
#  liable,
#  imprisonment,
#  years,
#  punished,
#  term,
#  description,
#  fine,
#  days,
#  kidnaps,
#  confinement,
#  war,
#  bangladesh,
#  taka,
#  abducts,
#  seven,
#  interested,
#  imports,
#  restrains,
#  intent,
#  disposed,
#  lawful,
#  murdered,
#  subjected,
#  custody,
#  year,
# -------------
# Cluster 6:
#  purpose,
#  coin,
#  bangladesh,
#  sufferer,
#  counterfeiting,
#  liable,
#  used,
#  imprisonment,
#  performs,
#  years,
#  war,
#  description,
#  process,
#  stamp,
#  fine,
#  term,
#  punished,
#  extend,
#  issued,
#  government,
#  knowing,
#  reason,
#  knowingly,
#  life,
#  age,
#  believe,
#  interested,
#  instrument,
#  counterfeit,
#  disposes,
# -------------
# Cluster 7:
#  simple,
#  extend,
#  taka,
#  legally,
#  notice,
#  offence,
#  required,
#  order,
#  public,
#  months,
#  servant,
#  summons,
#  intentionally,
#  bound,
#  information,
#  term,
#  fine,
#  imprisonment,
#  month,
#  provocation,
#  commission,
#  thousand,
#  competent,
#  punished,
#  omits,
#  time,
#  court,
#  given,
#  section,
#  bind,
# -------------

# %% [markdown]
# # Pie chart of the result

# %%
""""
# %matplotlib inline
import matplotlib.pyplot as plt

exp_vals = [2, 13, 4, 10]
exp_labels = ["Cluster 0", "Cluster 1", "Cluster 2", "Cluster 3"]

plt.pie(exp_vals,labels=exp_labels, shadow=True, autopct='%1.1f%%', radius=2.5)
#plt.axis("equal")
plt.show()
